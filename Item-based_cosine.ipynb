# %% [markdown]
# # Tiền xử lý

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

crawled_courses = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/HKN/HKN_project/Dataset/crawled_courses_information.csv")
coursera_reviews = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/HKN/HKN_project/Dataset/Coursera_reviews.csv")
coursera_courses = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/HKN/HKN_project/Dataset/Coursera_courses.csv")

# %%
coursera_courses.drop('name', axis = 1, inplace = True)
coursera_courses
# Out:
#                                     institution  \
# 0                           Stanford University
# 1                         University of Alberta
# 2                               Yale University
# 3                                        Google
# 4                     Google - Spectrum Sharing
# ..                                          ...
# 618  University of Illinois at Urbana-Champaign
# 619                 University of Manchester
# 620             University of California, Davis
# 621                       ESSEC Business School
# 622                    Johns Hopkins University
#
#                                             course_url  \
# 0      https://www.coursera.org/learn/machine-learning
# 1     https://www.coursera.org/learn/indigenous-canada
# 2    https://www.coursera.org/learn/the-science-of-...
# 3    https://www.coursera.org/learn/technical-suppo...
# 4    https://www.coursera.org/learn/google-cbrs-cpi...
# ..                                                 ...
# 618  https://www.coursera.org/learn/accounting-data...
# 619        https://www.coursera.org/learn/spectroscopy
# 620  https://www.coursera.org/learn/managing-as-a-c...
# 621  https://www.coursera.org/learn/hotel-distribution
# 622  https://www.coursera.org/learn/data-science-co...
#
#                             course_id
# 0                    machine-learning
# 1                   indigenous-canada
# 2           the-science-of-well-being
# 3      technical-support-fundamentals
# 4            google-cbrs-cpi-training
# ..                                ...
# 618  accounting-data-analytics-python
# 619                      spectroscopy
# 620               managing-as-a-coach
# 621                hotel-distribution
# 622               data-science-course
#
# [623 rows x 3 columns]

# %%
crawled_courses.rename(columns = {'rating':'avg_rating'}, inplace = True)
crawled_courses
# Out:
#                                                     name  \
# 0      Accounting for Mergers and Acquisitions: Found...
# 1                         Add Gore to Your Game in Unity
# 2             Add Ragdoll Effect to a Character in Unity
# 3                  Advanced Topics in Derivative Pricing
# 4      Approve Social Media Posts with Zapier and Trello
# ...                                                  ...
# 10250                                           컨볼루션 신경망
# 10251                             클라우드 컴퓨팅 기초(Cloud 101)
# 10252                                         파이썬 단기집중과정
# 10253                                     파이썬의 데이터 과학 소개
# 10254                                 파이썬의 응용 소셜 네트워크 분석
#
#                                                      url  \
# 0      https://www.coursera.org/learn/accounting-for-...
# 1      https://www.coursera.org/learn/add-gore-game-u...
# 2      https://www.coursera.org/learn/ragdoll-effect-...
# 3      https://www.coursera.org/learn/financial-engin...
# 4      https://www.coursera.org/learn/approve-social-...
# ...                                                  ...
# 10250  https://www.coursera.org/learn/convolutional-n...
# 10251  https://www.coursera.org/learn/cloud-computing...
# 10252  https://www.coursera.org/learn/python-crash-co...
# 10253  https://www.coursera.org/learn/python-data-ana...
# 10254  https://www.coursera.org/learn/python-social-n...
#
#                      category             subcategory  \
# 0                    Business                 Finance
# 1            Computer Science    Software Development
# 2            Computer Science    Software Development
# 3                    Business                 Finance
# 4                    Business               Marketing
# ...                       ...                     ...
# 10250            Data Science        Machine Learning
# 10251  Information Technology         Cloud Computing
# 10252  Information Technology  Support and Operations
# 10253            Data Science           Data Analysis
# 10254            Data Science           Data Analysis
#
#                                              instructors  \
# 0                                            Oktay Urcan
# 1                                         Edward Falzon
# 2                                         Edward Falzon
# 3                 Garud Iyengar, Ali Hirsa, Martin Haugh
# 4                                           Carmen Rojas
# ...                                                  ...
# 10250  Andrew Ng, Kian Katanforoosh, Younes Bensouda ...
# 10251                                       Jim Sullivan
# 10252                                       Jim Sullivan
# 10253                                 Christopher Brooks
# 10254                                      Daniel Romero
#
#                                              description  enrollment    views  \
# 0      This course aims at assisting you in interpret...         NaN  17460.0
# 1      In this one-hour, project-based course, you'll...         NaN      NaN
# 2      Unity Physics is a great mechanic that simulat...         NaN      NaN
# 3      This course discusses topics in derivative pri...      3476.0  13555.0
# 4      The process that marketing and communications ...         NaN      NaN
# ...                                                  ...         ...      ...
# 10250  딥 러닝 전문화의 네 번째 과정에서는 컴퓨터 비전이 어떻게 발전해 왔는지 이해하고 ...         NaN   2712.0
# 10251  클라우드 컴퓨팅 기초(Cloud 101)에 오신 것을 환영합니다. \n\n앞으로 몇...         NaN   1637.0
# 10252  이 과정은 가장 일반적인 구조를 사용하여 파이썬으로 간단한 프로그램을 작성하기 위한...      3129.0  17399.0
# 10253  이 과정에서는 학습자에게 람다, csv 파일 읽기 및 조작, numpy 라이브러리와...         NaN   1769.0
# 10254  이 과정은 NetworkX 라이브러리를 사용한 튜토리얼을 통해 학습자에게 네트워크 ...         NaN   1670.0
#
#        avg_rating  raters
# 0             NaN     NaN
# 1             NaN     NaN
# 2             NaN     NaN
# 3             NaN     NaN
# 4             NaN     NaN
# ...           ...     ...
# 10250         NaN     NaN
# 10251         4.6    20.0
# 10252         4.7    37.0
# 10253         NaN     NaN
# 10254         NaN     NaN
#
# [10255 rows x 10 columns]

# %%
courses = pd.merge(coursera_courses, crawled_courses, left_on = 'course_url', right_on = 'url')
courses.drop('url', axis = 1, inplace = True)
courses
# Out:
#                                     institution  \
# 0                           Stanford University
# 1                         University of Alberta
# 2                               Yale University
# 3                                        Google
# 4                     Google - Spectrum Sharing
# ..                                          ...
# 583  University of Illinois at Urbana-Champaign
# 584                 University of Manchester
# 585             University of California, Davis
# 586                       ESSEC Business School
# 587                    Johns Hopkins University
#
#                                             course_url  \
# 0      https://www.coursera.org/learn/machine-learning
# 1     https://www.coursera.org/learn/indigenous-canada
# 2    https://www.coursera.org/learn/the-science-of-...
# 3    https://www.coursera.org/learn/technical-suppo...
# 4    https://www.coursera.org/learn/google-cbrs-cpi...
# ..                                                 ...
# 583  https://www.coursera.org/learn/accounting-data...
# 584        https://www.coursera.org/learn/spectroscopy
# 585  https://www.coursera.org/learn/managing-as-a-c...
# 586  https://www.coursera.org/learn/hotel-distribution
# 587  https://www.coursera.org/learn/data-science-co...
#
#                             course_id  \
# 0                    machine-learning
# 1                   indigenous-canada
# 2           the-science-of-well-being
# 3      technical-support-fundamentals
# 4            google-cbrs-cpi-training
# ..                                ...
# 583  accounting-data-analytics-python
# 584                      spectroscopy
# 585               managing-as-a-coach
# 586                hotel-distribution
# 587               data-science-course
#
#                                                   name  \
# 0    Supervised Machine Learning: Regression and Cl...
# 1                                    Indigenous Canada
# 2                            The Science of Well-Being
# 3                       Technical Support Fundamentals
# 4    Become a CBRS Certified Professional Installer...
# ..                                                 ...
# 583              Accounting Data Analytics with Python
# 584             Introduction to Molecular Spectroscopy
# 585                                Managing as a Coach
# 586             The fundamentals of hotel distribution
# 587                     A Crash Course in Data Science
#
#                              category                subcategory  \
# 0                        Data Science           Machine Learning
# 1                 Arts and Humanities                    History
# 2                Personal Development       Personal Development
# 3              Information Technology     Support and Operations
# 4              Information Technology                 Networking
# ..                                ...                        ...
# 583                      Data Science              Data Analysis
# 584  Physical Science and Engineering                  Chemistry
# 585                          Business  Leadership and Management
# 586                          Business          Business Strategy
# 587                      Data Science              Data Analysis
#
#                                            instructors  \
# 0      Andrew Ng, Eddy Shyu, Aarti Bagul, Geoff Ladwig
# 1                                        Chelsea Vowel
# 2                                        Laurie Santos
# 3                           Google Career Certificates
# 4                                               Google
# ..                                                 ...
# 583                           Ronald Guymon, Linden Lu
# 584                           Patrick J O'Malley, D.Sc
# 585                                        Kris Plachy
# 586                       Peter O'Connor, Nicolas Graf
# 587  Jeff Leek, PhD, Brian Caffo, PhD, Roger D. Pen...
#
#                                            description  enrollment      views  \
# 0    In the first course of the Machine Learning Sp...    168561.0  2236026.0
# 1    Indigenous Canada is a 12-lesson Massive Open ...    509837.0   502929.0
# 2    In this course you will engage in a series of ...   4151165.0  1628508.0
# 3    This course is the first of a series that aims...   1299327.0  5045484.0
# 4    This six-module program, developed by Google, ...      2463.0    15960.0
# ..                                                 ...         ...        ...
# 583  This course focuses on developing Python skill...      9592.0    14919.0
# 584  The course introduces the three key spectrosco...     48324.0    29836.0
# 585  Do you (or do you want to) manage employees? H...     47082.0    35514.0
# 586  In today’s hotel sector an increasingly comple...     34003.0    31182.0
# 587  By now you have definitely heard about data sc...    188705.0    30824.0
#
#      avg_rating    raters
# 0           4.9    5226.0
# 1           4.8   20503.0
# 2           4.9   34870.0
# 3           4.8  128886.0
# 4           4.6     166.0
# ..          ...       ...
# 583         4.2      71.0
# 584         4.7    2233.0
# 585         4.7    1382.0
# 586         4.7    1237.0
# 587         4.5    8015.0
#
# [588 rows x 12 columns]

# %%
#import label encoder
from sklearn import preprocessing 
#make an instance of Label Encoder
label_encoder = preprocessing.LabelEncoder()
courses['courseId'] = label_encoder.fit_transform(courses['course_id'])
courses
# Out:
#                                     institution  \
# 0                           Stanford University
# 1                         University of Alberta
# 2                               Yale University
# 3                                        Google
# 4                     Google - Spectrum Sharing
# ..                                          ...
# 583  University of Illinois at Urbana-Champaign
# 584                 University of Manchester
# 585             University of California, Davis
# 586                       ESSEC Business School
# 587                    Johns Hopkins University
#
#                                             course_url  \
# 0      https://www.coursera.org/learn/machine-learning
# 1     https://www.coursera.org/learn/indigenous-canada
# 2    https://www.coursera.org/learn/the-science-of-...
# 3    https://www.coursera.org/learn/technical-suppo...
# 4    https://www.coursera.org/learn/google-cbrs-cpi...
# ..                                                 ...
# 583  https://www.coursera.org/learn/accounting-data...
# 584        https://www.coursera.org/learn/spectroscopy
# 585  https://www.coursera.org/learn/managing-as-a-c...
# 586  https://www.coursera.org/learn/hotel-distribution
# 587  https://www.coursera.org/learn/data-science-co...
#
#                             course_id  \
# 0                    machine-learning
# 1                   indigenous-canada
# 2           the-science-of-well-being
# 3      technical-support-fundamentals
# 4            google-cbrs-cpi-training
# ..                                ...
# 583  accounting-data-analytics-python
# 584                      spectroscopy
# 585               managing-as-a-coach
# 586                hotel-distribution
# 587               data-science-course
#
#                                                   name  \
# 0    Supervised Machine Learning: Regression and Cl...
# 1                                    Indigenous Canada
# 2                            The Science of Well-Being
# 3                       Technical Support Fundamentals
# 4    Become a CBRS Certified Professional Installer...
# ..                                                 ...
# 583              Accounting Data Analytics with Python
# 584             Introduction to Molecular Spectroscopy
# 585                                Managing as a Coach
# 586             The fundamentals of hotel distribution
# 587                     A Crash Course in Data Science
#
#                              category                subcategory  \
# 0                        Data Science           Machine Learning
# 1                 Arts and Humanities                    History
# 2                Personal Development       Personal Development
# 3              Information Technology     Support and Operations
# 4              Information Technology                 Networking
# ..                                ...                        ...
# 583                      Data Science              Data Analysis
# 584  Physical Science and Engineering                  Chemistry
# 585                          Business  Leadership and Management
# 586                          Business          Business Strategy
# 587                      Data Science              Data Analysis
#
#                                            instructors  \
# 0      Andrew Ng, Eddy Shyu, Aarti Bagul, Geoff Ladwig
# 1                                        Chelsea Vowel
# 2                                        Laurie Santos
# 3                           Google Career Certificates
# 4                                               Google
# ..                                                 ...
# 583                           Ronald Guymon, Linden Lu
# 584                           Patrick J O'Malley, D.Sc
# 585                                        Kris Plachy
# 586                       Peter O'Connor, Nicolas Graf
# 587  Jeff Leek, PhD, Brian Caffo, PhD, Roger D. Pen...
#
#                                            description  enrollment      views  \
# 0    In the first course of the Machine Learning Sp...    168561.0  2236026.0
# 1    Indigenous Canada is a 12-lesson Massive Open ...    509837.0   502929.0
# 2    In this course you will engage in a series of ...   4151165.0  1628508.0
# 3    This course is the first of a series that aims...   1299327.0  5045484.0
# 4    This six-module program, developed by Google, ...      2463.0    15960.0
# ..                                                 ...         ...        ...
# 583  This course focuses on developing Python skill...      9592.0    14919.0
# 584  The course introduces the three key spectrosco...     48324.0    29836.0
# 585  Do you (or do you want to) manage employees? H...     47082.0    35514.0
# 586  In today’s hotel sector an increasingly comple...     34003.0    31182.0
# 587  By now you have definitely heard about data sc...    188705.0    30824.0
#
#      avg_rating    raters  courseId
# 0           4.9    5226.0       334
# 1           4.8   20503.0       266
# 2           4.9   34870.0       523
# 3           4.8  128886.0       517
# 4           4.6     166.0       244
# ..          ...       ...       ...
# 583         4.2      71.0         3
# 584         4.7    2233.0       494
# 585         4.7    1382.0       343
# 586         4.7    1237.0       257
# 587         4.5    8015.0       117
#
# [588 rows x 13 columns]

# %%
len(courses)
# Out:
# 588

# %%
len(coursera_reviews)
# Out:
# 1454711

# %%
ratings = coursera_reviews.drop_duplicates()
len(ratings)
# Out:
# 519947

# %%
ratings = pd.merge(ratings, courses)
ratings['userId'] = label_encoder.fit_transform(ratings[['reviewers']])
ratings
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#                                                   reviews       reviewers  \
# 0       Pretty dry, but I was able to pass with just t...     By Robert S
# 1       would be a better experience if the video and ...  By Gabriel E R
# 2       Information was perfect! The program itself wa...      By Jacob D
# 3       A few grammatical mistakes on test made me do ...       By Dale B
# 4       Excellent course and the training provided was...       By Sean G
# ...                                                   ...             ...
# 506896                                     Great teacher!   By George B S
# 506897                                     Very satisfied  By Abubakarr K
# 506898                                     awesome course      By MD. I H
# 506899                                     Comprehensive!     By James  K
# 506900                                     Great Course!!    By Eduardo R
#
#         date_reviews  rating                       course_id  \
# 0       Feb 12, 2020       4        google-cbrs-cpi-training
# 1       Sep 28, 2020       4        google-cbrs-cpi-training
# 2       Apr 08, 2020       4        google-cbrs-cpi-training
# 3       Feb 24, 2020       4        google-cbrs-cpi-training
# 4       Jun 18, 2020       4        google-cbrs-cpi-training
# ...              ...     ...                             ...
# 506896  Jul 16, 2018       5  technical-support-fundamentals
# 506897  Jun 13, 2018       5  technical-support-fundamentals
# 506898  May 28, 2018       5  technical-support-fundamentals
# 506899  May 28, 2018       5  technical-support-fundamentals
# 506900  Apr 03, 2018       5  technical-support-fundamentals
#
#                       institution  \
# 0       Google - Spectrum Sharing
# 1       Google - Spectrum Sharing
# 2       Google - Spectrum Sharing
# 3       Google - Spectrum Sharing
# 4       Google - Spectrum Sharing
# ...                           ...
# 506896                     Google
# 506897                     Google
# 506898                     Google
# 506899                     Google
# 506900                     Google
#
#                                                course_url  \
# 0       https://www.coursera.org/learn/google-cbrs-cpi...
# 1       https://www.coursera.org/learn/google-cbrs-cpi...
# 2       https://www.coursera.org/learn/google-cbrs-cpi...
# 3       https://www.coursera.org/learn/google-cbrs-cpi...
# 4       https://www.coursera.org/learn/google-cbrs-cpi...
# ...                                                   ...
# 506896  https://www.coursera.org/learn/technical-suppo...
# 506897  https://www.coursera.org/learn/technical-suppo...
# 506898  https://www.coursera.org/learn/technical-suppo...
# 506899  https://www.coursera.org/learn/technical-suppo...
# 506900  https://www.coursera.org/learn/technical-suppo...
#
#                                                      name  \
# 0       Become a CBRS Certified Professional Installer...
# 1       Become a CBRS Certified Professional Installer...
# 2       Become a CBRS Certified Professional Installer...
# 3       Become a CBRS Certified Professional Installer...
# 4       Become a CBRS Certified Professional Installer...
# ...                                                   ...
# 506896                     Technical Support Fundamentals
# 506897                     Technical Support Fundamentals
# 506898                     Technical Support Fundamentals
# 506899                     Technical Support Fundamentals
# 506900                     Technical Support Fundamentals
#
#                       category             subcategory  \
# 0       Information Technology              Networking
# 1       Information Technology              Networking
# 2       Information Technology              Networking
# 3       Information Technology              Networking
# 4       Information Technology              Networking
# ...                        ...                     ...
# 506896  Information Technology  Support and Operations
# 506897  Information Technology  Support and Operations
# 506898  Information Technology  Support and Operations
# 506899  Information Technology  Support and Operations
# 506900  Information Technology  Support and Operations
#
#                        instructors  \
# 0                           Google
# 1                           Google
# 2                           Google
# 3                           Google
# 4                           Google
# ...                            ...
# 506896  Google Career Certificates
# 506897  Google Career Certificates
# 506898  Google Career Certificates
# 506899  Google Career Certificates
# 506900  Google Career Certificates
#
#                                               description  enrollment  \
# 0       This six-module program, developed by Google, ...      2463.0
# 1       This six-module program, developed by Google, ...      2463.0
# 2       This six-module program, developed by Google, ...      2463.0
# 3       This six-module program, developed by Google, ...      2463.0
# 4       This six-module program, developed by Google, ...      2463.0
# ...                                                   ...         ...
# 506896  This course is the first of a series that aims...   1299327.0
# 506897  This course is the first of a series that aims...   1299327.0
# 506898  This course is the first of a series that aims...   1299327.0
# 506899  This course is the first of a series that aims...   1299327.0
# 506900  This course is the first of a series that aims...   1299327.0
#
#             views  avg_rating    raters  courseId  userId
# 0         15960.0         4.6     166.0       244  196695
# 1         15960.0         4.6     166.0       244   78640
# 2         15960.0         4.6     166.0       244   99768
# 3         15960.0         4.6     166.0       244   52735
# 4         15960.0         4.6     166.0       244  211721
# ...           ...         ...       ...       ...     ...
# 506896  5045484.0         4.8  128886.0       517   80583
# 506897  5045484.0         4.8  128886.0       517    7628
# 506898  5045484.0         4.8  128886.0       517  137694
# 506899  5045484.0         4.8  128886.0       517  100912
# 506900  5045484.0         4.8  128886.0       517   65582
#
# [506901 rows x 18 columns]

# %%
len(ratings)
# Out:
# 506901

# %%
ratings = ratings[['reviews', 'reviewers', 'userId', 'courseId', 'date_reviews', 'rating']]
ratings
# Out:
#                                                   reviews       reviewers  \
# 0       Pretty dry, but I was able to pass with just t...     By Robert S
# 1       would be a better experience if the video and ...  By Gabriel E R
# 2       Information was perfect! The program itself wa...      By Jacob D
# 3       A few grammatical mistakes on test made me do ...       By Dale B
# 4       Excellent course and the training provided was...       By Sean G
# ...                                                   ...             ...
# 506896                                     Great teacher!   By George B S
# 506897                                     Very satisfied  By Abubakarr K
# 506898                                     awesome course      By MD. I H
# 506899                                     Comprehensive!     By James  K
# 506900                                     Great Course!!    By Eduardo R
#
#         userId  courseId  date_reviews  rating
# 0       196695       244  Feb 12, 2020       4
# 1        78640       244  Sep 28, 2020       4
# 2        99768       244  Apr 08, 2020       4
# 3        52735       244  Feb 24, 2020       4
# 4       211721       244  Jun 18, 2020       4
# ...        ...       ...           ...     ...
# 506896   80583       517  Jul 16, 2018       5
# 506897    7628       517  Jun 13, 2018       5
# 506898  137694       517  May 28, 2018       5
# 506899  100912       517  May 28, 2018       5
# 506900   65582       517  Apr 03, 2018       5
#
# [506901 rows x 6 columns]

# %%
ratings = ratings.sort_values(by = ['date_reviews'])
ratings
# Out:
#                                                   reviews        reviewers  \
# 459119  This course is for you if you really don't kno...  By Sander v d O
# 92082   This is a very useful course. Give you a pract...      By Wilmar A
# 273757  This course provides a broad overview of the e...         By Jon M
# 218710  I give this course 5 stars! I learned a lot an...      By Justin R
# 369317  The Best course so far in cousera!!! Loved it!...          By Ritu
# ...                                                   ...              ...
# 380204           teachers and course design is very good      By shravan m
# 318855           Excellent teaching sir,thank you so much     By Vishnu p
# 361681  Kinda complicated on the statistics front if y...   By Prateek A P
# 209890  Es un excelente curso para repasar fisiología ...   By Esteban S M
# 401073  The lessons are very informative. I learned a ...    By Mariel D A
#
#         userId  courseId  date_reviews  rating
# 459119  208300       361  Apr 01, 2016       3
# 92082   247024       329  Apr 01, 2016       5
# 273757  108516       565  Apr 01, 2016       4
# 218710  114688       346  Apr 01, 2016       5
# 369317  196257       573  Apr 01, 2016       5
# ...        ...       ...           ...     ...
# 380204  272245       426  Sep 30, 2020       4
# 318855  243649       351  Sep 30, 2020       5
# 361681  184298       449  Sep 30, 2020       4
# 209890   70487       405  Sep 30, 2020       5
# 401073  145766       190  Sep 30, 2020       5
#
# [506901 rows x 6 columns]

# %%
ratings = ratings.drop_duplicates(
  subset = ['courseId', 'userId'],
  keep = 'last').reset_index(drop = True)

# %%
len(ratings)
# Out:
# 493274

# %%
len(ratings[['userId']].drop_duplicates())
# Out:
# 282025

# %%
df = ratings.groupby('userId')['rating'].count().reset_index(name = 'count')
df = pd.DataFrame(df)
df = df[df['count'] > 20]
df
# Out:
#         userId  count
# 1781      1781     32
# 4287      4287     30
# 5107      5107     25
# 5153      5153     22
# 6011      6011     27
# ...        ...    ...
# 249950  249950     31
# 249963  249963     22
# 249973  249973     24
# 249999  249999     28
# 254196  254196     24
#
# [880 rows x 2 columns]

# %%
ratings = ratings.loc[ratings['userId'].isin(df['userId'])]
len(ratings)
# Out:
# 27837

# %%
from sklearn.model_selection import train_test_split
X_train, X_test = train_test_split(ratings, test_size = 0.01, random_state = 42)

# %%
len(X_train)
# Out:
# 27558

# %%
len(X_test)
# Out:
# 279

# %%
X_test = X_test[['userId', 'courseId', 'rating']]
X_train = X_train[['userId', 'courseId', 'rating']]

# %%
X_test1 = X_test.copy()
X_test1.iloc[:,2] = 0
X_test1
# Out:
#         userId  courseId  rating
# 320025  184316       125       0
# 258282  108149       314       0
# 5213    128369       236       0
# 460016   55334       396       0
# 272398   20281       126       0
# ...        ...       ...     ...
# 52706    20866       414       0
# 422062  189812       440       0
# 20718    14139       201       0
# 370987    7020       346       0
# 473046   34606       329       0
#
# [279 rows x 3 columns]

# %%
X_train = pd.concat([X_train, X_test1], axis = 0)
len(X_train[['userId']].drop_duplicates())
# Out:
# 880

# %%
len(X_train[['courseId']].drop_duplicates())
# Out:
# 555

# %%
X_train = X_train.pivot_table(index = 'courseId', columns = 'userId', values = 'rating').fillna(0)
df1 = X_train.copy()

# %%
def get_coursename(courseid):
  return (courses.loc[(courses.courseId == courseid), 'name'].iloc[0])

# %%
def recommend_courses(user, df):

  recommended_courses = []
  recommendations = []

  for m in df[df[user] == 0].index.tolist():

    index_df = df.index.tolist().index(m)
    predicted_rating = df1.iloc[index_df, df1.columns.tolist().index(user)]
    recommended_courses.append((m, predicted_rating))

  sorted_rm = sorted(recommended_courses, key = lambda x:x[1], reverse = True)
  
  for recommended_course in sorted_rm:
    recommendations.append(((recommended_course[0], get_coursename(recommended_course[0]), recommended_course[1])))
  return recommendations

# %%
from sklearn.neighbors import NearestNeighbors
def get_recommendation(user, num_neighbors, df):
# find the nearest neighbors using NearestNeighbors(n_neighbors=3)
  number_neighbors = num_neighbors
  knn = NearestNeighbors(metric = 'cosine', algorithm = 'brute')
  knn.fit(df.values)
  distances, indices = knn.kneighbors(df.values, n_neighbors = number_neighbors)

  #indices shows the nearest courses to each course. 
  #Each row corresponds to the row in the df. The first element in a row is the most similar (nearest) course. 
  #distances shows the distance between courses. Each number in this matrix corresponds to the number in the indices matrix.

  # convert user_name to user_index
  user_index = df.columns.tolist().index(user)

  # t: course_id, m: the row number of t in df
  for m,t in list(enumerate(df.index)):
    
    # find courses without ratings by user
    if df.iloc[m, user_index] == 0:
      sim_courses = indices[m].tolist()
      course_distances = distances[m].tolist()
      
      if m in sim_courses:
        id_course = sim_courses.index(m)
        sim_courses.remove(m)
        course_distances.pop(id_course) 

      else:
        sim_courses = sim_courses[:number_neighbors-1]
        course_distances = course_distances[:number_neighbors-1]
          
      # course_similarty = 1 - course_distance    
      course_similarity = [1-x for x in course_distances]
      course_similarity_copy = course_similarity.copy()
      nominator = 0

      # for each similar course
      for s in range(0, len(course_similarity)):
        
        # check if the rating of a similar course is zero
        if df.iloc[sim_courses[s], user_index] == 0:

          # if the rating is zero, ignore the rating and the similarity in calculating the predicted rating
          if len(course_similarity_copy) == (number_neighbors - 1):
            course_similarity_copy.pop(s)
            
          else:
            course_similarity_copy.pop(s-(len(course_similarity)-len(course_similarity_copy)))

        # if the rating is not zero, use the rating and similarity in the calculation
        else:
          nominator = nominator + course_similarity[s]*df.iloc[sim_courses[s],user_index]

      # check if the number of the ratings with non-zero is positive
      if len(course_similarity_copy) > 0:
        
        # check if the sum of the ratings of the similar courses is positive.
        if sum(course_similarity_copy) > 0:
          predicted_r = nominator/sum(course_similarity_copy)
        # Even if there are some courses for which the ratings are positive, some courses have zero similarity even though they are selected as similar courses.
        # in this case, the predicted rating becomes zero as well  
        else:
          predicted_r = 0

      # if all the ratings of the similar courses are zero, then predicted rating should be zero
      else:
        predicted_r = 0

    # place the predicted rating into the copy of the original dataset
      df1.iloc[m,user_index] = predicted_r
  return recommend_courses(user, df)

# %%
get_recommendation(46967, 10, X_train)[:10]
# Out:
# [(397, 'Primeros Auxilios Psicológicos (PAP)', 5.000000000000001),
#  (5, 'The Addicted Brain', 5.0),
#  (10, 'AI for Medical Diagnosis', 5.0),
#  (21, 'Anticorrupción: Introducción a conceptos y perspectiva práctica', 5.0),
#  (23,
#   'Aprendiendo a aprender: Poderosas herramientas mentales con las que podrás dominar temas difíciles (Learning How to Learn)',
#   5.0),
#  (41, 'Big History: Connecting Knowledge', 5.0),
#  (53, 'Business Transformation with Google Cloud', 5.0),
#  (55,
#   'Camino a la Excelencia en Gestión de Proyectos (Pontificia Universidad Católica de Chile)',
#   5.0),
#  (68,
#   'Natural Language Processing with Classification and Vector Spaces',
#   5.0),
#  (70, 'Understanding Clinical Research: Behind the Statistics', 5.0)]

# %%
def get_recommendation_4test(test):

  X_test_pred = []
  X_test_userid = X_test['userId'].tolist()   
  X_test_courseid = X_test['courseId'].tolist()
 
  print("------Dự đoán cho tập test với {} điểm dữ liệu -----------".format(len(X_test_userid)))
  
  for i in range(len(X_test_userid)):      
    list_R = get_recommendation(X_test_userid[i], 10, X_train)  
    check = 0
    for j in list_R:
      if(X_test_courseid[i] == j[0]):     
        X_test_pred.append(j[2])
        check = 1
    if(check == 0):
      X_test_pred.append(0)
    print('----- Đang dự đoán cho dòng thứ {}'.format(i), 'là {}'.format(X_test_pred[i])) 
  return X_test_pred

# %%
import time
start = time.time()

X_test_pred_rating = get_recommendation_4test(X_test)

end = time.time()
print('Tổng thời gian dự đoán: ', end - start)
# Out:
# ------Dự đoán cho tập test với 279 điểm dữ liệu -----------
# ----- Đang dự đoán cho dòng thứ 0 là 4.4573692015197315
# ----- Đang dự đoán cho dòng thứ 1 là 3.961067926607112
# ----- Đang dự đoán cho dòng thứ 2 là 0.0
# ----- Đang dự đoán cho dòng thứ 3 là 0.0
# ----- Đang dự đoán cho dòng thứ 4 là 5.0
# ----- Đang dự đoán cho dòng thứ 5 là 4.75941418384205
# ----- Đang dự đoán cho dòng thứ 6 là 4.48738421136186
# ----- Đang dự đoán cho dòng thứ 7 là 5.0
# ----- Đang dự đoán cho dòng thứ 8 là 0.0
# ----- Đang dự đoán cho dòng thứ 9 là 4.837879124834856
# ----- Đang dự đoán cho dòng thứ 10 là 3.690869580058226
# ----- Đang dự đoán cho dòng thứ 11 là 3.652723161728985
# ----- Đang dự đoán cho dòng thứ 12 là 4.0
# ----- Đang dự đoán cho dòng thứ 13 là 5.0
# ----- Đang dự đoán cho dòng thứ 14 là 4.702515998577623
# ----- Đang dự đoán cho dòng thứ 15 là 5.0
# ----- Đang dự đoán cho dòng thứ 16 là 5.000000000000001
# ----- Đang dự đoán cho dòng thứ 17 là 4.382259798901592
# ----- Đang dự đoán cho dòng thứ 18 là 4.850412668475743
# ----- Đang dự đoán cho dòng thứ 19 là 0.0
# ----- Đang dự đoán cho dòng thứ 20 là 2.111402372892952
# ----- Đang dự đoán cho dòng thứ 21 là 5.0
# ----- Đang dự đoán cho dòng thứ 22 là 4.378574084770225
# ----- Đang dự đoán cho dòng thứ 23 là 5.0
# ----- Đang dự đoán cho dòng thứ 24 là 4.754112799219366
# ----- Đang dự đoán cho dòng thứ 25 là 2.2956054484967328
# ----- Đang dự đoán cho dòng thứ 26 là 4.699736301145023
# ----- Đang dự đoán cho dòng thứ 27 là 4.732890156771692
# ----- Đang dự đoán cho dòng thứ 28 là 4.772735821303947
# ----- Đang dự đoán cho dòng thứ 29 là 4.7965891832120136
# ----- Đang dự đoán cho dòng thứ 30 là 4.999999999999999
# ----- Đang dự đoán cho dòng thứ 31 là 4.382568638327265
# ----- Đang dự đoán cho dòng thứ 32 là 4.887885333577761
# ----- Đang dự đoán cho dòng thứ 33 là 4.591605218717588
# ----- Đang dự đoán cho dòng thứ 34 là 0.0
# ----- Đang dự đoán cho dòng thứ 35 là 4.251188848331432
# ----- Đang dự đoán cho dòng thứ 36 là 4.781572971811076
# ----- Đang dự đoán cho dòng thứ 37 là 4.705676143140191
# ----- Đang dự đoán cho dòng thứ 38 là 0.0
# ----- Đang dự đoán cho dòng thứ 39 là 4.999999999999999
# ----- Đang dự đoán cho dòng thứ 40 là 4.787948181357647
# ----- Đang dự đoán cho dòng thứ 41 là 4.074072605821898
# ----- Đang dự đoán cho dòng thứ 42 là 4.461600405932012
# ----- Đang dự đoán cho dòng thứ 43 là 4.8779214394863315
# ----- Đang dự đoán cho dòng thứ 44 là 4.687868025415675
# ----- Đang dự đoán cho dòng thứ 45 là 4.644534893546193
# ----- Đang dự đoán cho dòng thứ 46 là 4.842642695017224
# ----- Đang dự đoán cho dòng thứ 47 là 4.8156553401100535
# ----- Đang dự đoán cho dòng thứ 48 là 4.722914283968828
# ----- Đang dự đoán cho dòng thứ 49 là 5.0
# ----- Đang dự đoán cho dòng thứ 50 là 4.833175874881683
# ----- Đang dự đoán cho dòng thứ 51 là 4.769731599285621
# ----- Đang dự đoán cho dòng thứ 52 là 4.707211745935224
# ----- Đang dự đoán cho dòng thứ 53 là 4.863664739468303
# ----- Đang dự đoán cho dòng thứ 54 là 5.000000000000001
# ----- Đang dự đoán cho dòng thứ 55 là 5.0
# ----- Đang dự đoán cho dòng thứ 56 là 4.760925680357202
# ----- Đang dự đoán cho dòng thứ 57 là 4.61168368453235
# ----- Đang dự đoán cho dòng thứ 58 là 4.875524730852037
# ----- Đang dự đoán cho dòng thứ 59 là 5.0
# ----- Đang dự đoán cho dòng thứ 60 là 5.0
# ----- Đang dự đoán cho dòng thứ 61 là 4.625879867372576
# ----- Đang dự đoán cho dòng thứ 62 là 4.678066772477725
# ----- Đang dự đoán cho dòng thứ 63 là 4.841156035905047
# ----- Đang dự đoán cho dòng thứ 64 là 4.661313146082635
# ----- Đang dự đoán cho dòng thứ 65 là 0.0
# ----- Đang dự đoán cho dòng thứ 66 là 4.0
# ----- Đang dự đoán cho dòng thứ 67 là 4.158509258141278
# ----- Đang dự đoán cho dòng thứ 68 là 4.515474676641006
# ----- Đang dự đoán cho dòng thứ 69 là 0.0
# ----- Đang dự đoán cho dòng thứ 70 là 5.0
# ----- Đang dự đoán cho dòng thứ 71 là 4.823830242205793
# ----- Đang dự đoán cho dòng thứ 72 là 4.65669075132836
# ----- Đang dự đoán cho dòng thứ 73 là 4.8298555538523305
# ----- Đang dự đoán cho dòng thứ 74 là 5.000000000000001
# ----- Đang dự đoán cho dòng thứ 75 là 4.771188440760325
# ----- Đang dự đoán cho dòng thứ 76 là 5.0
# ----- Đang dự đoán cho dòng thứ 77 là 0.0
# ----- Đang dự đoán cho dòng thứ 78 là 4.761517787217856
# ----- Đang dự đoán cho dòng thứ 79 là 4.216622565910477
# ----- Đang dự đoán cho dòng thứ 80 là 4.524932743597628
# ----- Đang dự đoán cho dòng thứ 81 là 5.0
# ----- Đang dự đoán cho dòng thứ 82 là 4.496393892351043
# ----- Đang dự đoán cho dòng thứ 83 là 0.0
# ----- Đang dự đoán cho dòng thứ 84 là 4.250705980213158
# ----- Đang dự đoán cho dòng thứ 85 là 4.618842956202879
# ----- Đang dự đoán cho dòng thứ 86 là 4.020705037606158
# ----- Đang dự đoán cho dòng thứ 87 là 5.0
# ----- Đang dự đoán cho dòng thứ 88 là 3.0
# ----- Đang dự đoán cho dòng thứ 89 là 4.21341926260493
# ----- Đang dự đoán cho dòng thứ 90 là 4.425830630354427
# ----- Đang dự đoán cho dòng thứ 91 là 4.490819058265538
# ----- Đang dự đoán cho dòng thứ 92 là 4.4108955877981915
# ----- Đang dự đoán cho dòng thứ 93 là 4.999999999999999
# ----- Đang dự đoán cho dòng thứ 94 là 4.184166284595709
# ----- Đang dự đoán cho dòng thứ 95 là 0.0
# ----- Đang dự đoán cho dòng thứ 96 là 5.0
# ----- Đang dự đoán cho dòng thứ 97 là 4.0
# ----- Đang dự đoán cho dòng thứ 98 là 5.0
# ----- Đang dự đoán cho dòng thứ 99 là 5.0
# ----- Đang dự đoán cho dòng thứ 100 là 4.8671726078887
# ----- Đang dự đoán cho dòng thứ 101 là 5.0
# ----- Đang dự đoán cho dòng thứ 102 là 5.0
# ----- Đang dự đoán cho dòng thứ 103 là 4.3817657776168275
# ----- Đang dự đoán cho dòng thứ 104 là 5.0
# ----- Đang dự đoán cho dòng thứ 105 là 2.4258521779341575
# ----- Đang dự đoán cho dòng thứ 106 là 5.0
# ----- Đang dự đoán cho dòng thứ 107 là 4.622523209286977
# ----- Đang dự đoán cho dòng thứ 108 là 5.000000000000001
# ----- Đang dự đoán cho dòng thứ 109 là 4.999999999999999
# ----- Đang dự đoán cho dòng thứ 110 là 4.015463431906519
# ----- Đang dự đoán cho dòng thứ 111 là 4.8554454846727095
# ----- Đang dự đoán cho dòng thứ 112 là 4.402386930050654
# ----- Đang dự đoán cho dòng thứ 113 là 3.617540566986453
# ----- Đang dự đoán cho dòng thứ 114 là 5.0
# ----- Đang dự đoán cho dòng thứ 115 là 5.0
# ----- Đang dự đoán cho dòng thứ 116 là 5.000000000000001
# ----- Đang dự đoán cho dòng thứ 117 là 4.590628059572465
# ----- Đang dự đoán cho dòng thứ 118 là 4.32330968763065
# ----- Đang dự đoán cho dòng thứ 119 là 5.0
# ----- Đang dự đoán cho dòng thứ 120 là 5.0
# ----- Đang dự đoán cho dòng thứ 121 là 5.0
# ----- Đang dự đoán cho dòng thứ 122 là 5.0
# ----- Đang dự đoán cho dòng thứ 123 là 4.467216386899127
# ----- Đang dự đoán cho dòng thứ 124 là 5.0
# ----- Đang dự đoán cho dòng thứ 125 là 4.900386357245214
# ----- Đang dự đoán cho dòng thứ 126 là 5.0
# ----- Đang dự đoán cho dòng thứ 127 là 5.0
# ----- Đang dự đoán cho dòng thứ 128 là 5.0
# ----- Đang dự đoán cho dòng thứ 129 là 4.432510910558658
# ----- Đang dự đoán cho dòng thứ 130 là 4.788043915299247
# ----- Đang dự đoán cho dòng thứ 131 là 3.561813316758794
# ----- Đang dự đoán cho dòng thứ 132 là 4.728789249188228
# ----- Đang dự đoán cho dòng thứ 133 là 5.0
# ----- Đang dự đoán cho dòng thứ 134 là 4.999999999999999
# ----- Đang dự đoán cho dòng thứ 135 là 4.790415997416638
# ----- Đang dự đoán cho dòng thứ 136 là 4.868915220579748
# ----- Đang dự đoán cho dòng thứ 137 là 4.999999999999999
# ----- Đang dự đoán cho dòng thứ 138 là 4.999999999999999
# ----- Đang dự đoán cho dòng thứ 139 là 4.816443918671852
# ----- Đang dự đoán cho dòng thứ 140 là 4.8897233138963845
# ----- Đang dự đoán cho dòng thứ 141 là 5.000000000000001
# ----- Đang dự đoán cho dòng thứ 142 là 4.650812705468486
# ----- Đang dự đoán cho dòng thứ 143 là 5.0
# ----- Đang dự đoán cho dòng thứ 144 là 5.0
# ----- Đang dự đoán cho dòng thứ 145 là 5.0
# ----- Đang dự đoán cho dòng thứ 146 là 5.0
# ----- Đang dự đoán cho dòng thứ 147 là 4.753814669733557
# ----- Đang dự đoán cho dòng thứ 148 là 0.0
# ----- Đang dự đoán cho dòng thứ 149 là 0.0
# ----- Đang dự đoán cho dòng thứ 150 là 4.337682916690805
# ----- Đang dự đoán cho dòng thứ 151 là 0.0
# ----- Đang dự đoán cho dòng thứ 152 là 4.556873105959631
# ----- Đang dự đoán cho dòng thứ 153 là 4.643719809756462
# ----- Đang dự đoán cho dòng thứ 154 là 5.0
# ----- Đang dự đoán cho dòng thứ 155 là 5.0
# ----- Đang dự đoán cho dòng thứ 156 là 0.0
# ----- Đang dự đoán cho dòng thứ 157 là 4.565859124737871
# ----- Đang dự đoán cho dòng thứ 158 là 5.0
# ----- Đang dự đoán cho dòng thứ 159 là 5.0
# ----- Đang dự đoán cho dòng thứ 160 là 4.632140272173485
# ----- Đang dự đoán cho dòng thứ 161 là 4.888956457756872
# ----- Đang dự đoán cho dòng thứ 162 là 4.864497231241529
# ----- Đang dự đoán cho dòng thứ 163 là 3.5580542568981324
# ----- Đang dự đoán cho dòng thứ 164 là 4.999999999999999
# ----- Đang dự đoán cho dòng thứ 165 là 5.0
# ----- Đang dự đoán cho dòng thứ 166 là 4.999999999999999
# ----- Đang dự đoán cho dòng thứ 167 là 5.0
# ----- Đang dự đoán cho dòng thứ 168 là 3.0
# ----- Đang dự đoán cho dòng thứ 169 là 4.574752999324269
# ----- Đang dự đoán cho dòng thứ 170 là 5.0
# ----- Đang dự đoán cho dòng thứ 171 là 4.704301077958514
# ----- Đang dự đoán cho dòng thứ 172 là 4.492823227367729
# ----- Đang dự đoán cho dòng thứ 173 là 4.544060383330701
# ----- Đang dự đoán cho dòng thứ 174 là 5.0
# ----- Đang dự đoán cho dòng thứ 175 là 4.61555794703967
# ----- Đang dự đoán cho dòng thứ 176 là 4.638335908080385
# ----- Đang dự đoán cho dòng thứ 177 là 4.790424533144247
# ----- Đang dự đoán cho dòng thứ 178 là 4.0
# ----- Đang dự đoán cho dòng thứ 179 là 5.0
# ----- Đang dự đoán cho dòng thứ 180 là 3.840651411212476
# ----- Đang dự đoán cho dòng thứ 181 là 4.999999999999999
# ----- Đang dự đoán cho dòng thứ 182 là 4.745134530292528
# ----- Đang dự đoán cho dòng thứ 183 là 5.0
# ----- Đang dự đoán cho dòng thứ 184 là 0.0
# ----- Đang dự đoán cho dòng thứ 185 là 3.205226276716558
# ----- Đang dự đoán cho dòng thứ 186 là 0.0
# ----- Đang dự đoán cho dòng thứ 187 là 0.0
# ----- Đang dự đoán cho dòng thứ 188 là 5.0
# ----- Đang dự đoán cho dòng thứ 189 là 5.0
# ----- Đang dự đoán cho dòng thứ 190 là 4.675412716982664
# ----- Đang dự đoán cho dòng thứ 191 là 5.0
# ----- Đang dự đoán cho dòng thứ 192 là 4.86036833551842
# ----- Đang dự đoán cho dòng thứ 193 là 0.0
# ----- Đang dự đoán cho dòng thứ 194 là 4.548589299261978
# ----- Đang dự đoán cho dòng thứ 195 là 4.784518674954167
# ----- Đang dự đoán cho dòng thứ 196 là 0.0
# ----- Đang dự đoán cho dòng thứ 197 là 5.0
# ----- Đang dự đoán cho dòng thứ 198 là 0.0
# ----- Đang dự đoán cho dòng thứ 199 là 4.59269093042273
# ----- Đang dự đoán cho dòng thứ 200 là 4.876741733967021
# ----- Đang dự đoán cho dòng thứ 201 là 0.0
# ----- Đang dự đoán cho dòng thứ 202 là 5.0
# ----- Đang dự đoán cho dòng thứ 203 là 4.833530226498421
# ----- Đang dự đoán cho dòng thứ 204 là 5.0
# ----- Đang dự đoán cho dòng thứ 205 là 4.743519086434194
# ----- Đang dự đoán cho dòng thứ 206 là 3.413403226004456
# ----- Đang dự đoán cho dòng thứ 207 là 0.0
# ----- Đang dự đoán cho dòng thứ 208 là 3.446508835323214
# ----- Đang dự đoán cho dòng thứ 209 là 5.0
# ----- Đang dự đoán cho dòng thứ 210 là 5.0
# ----- Đang dự đoán cho dòng thứ 211 là 5.000000000000001
# ----- Đang dự đoán cho dòng thứ 212 là 5.0
# ----- Đang dự đoán cho dòng thứ 213 là 4.892765596551754
# ----- Đang dự đoán cho dòng thứ 214 là 4.66472670361497
# ----- Đang dự đoán cho dòng thứ 215 là 4.721015663235223
# ----- Đang dự đoán cho dòng thứ 216 là 5.000000000000001
# ----- Đang dự đoán cho dòng thứ 217 là 4.2370868388592395
# ----- Đang dự đoán cho dòng thứ 218 là 4.79576224761652
# ----- Đang dự đoán cho dòng thứ 219 là 5.0
# ----- Đang dự đoán cho dòng thứ 220 là 3.6752822183605343
# ----- Đang dự đoán cho dòng thứ 221 là 5.0
# ----- Đang dự đoán cho dòng thứ 222 là 0.0
# ----- Đang dự đoán cho dòng thứ 223 là 4.0383011033948115
# ----- Đang dự đoán cho dòng thứ 224 là 5.0
# ----- Đang dự đoán cho dòng thứ 225 là 5.0
# ----- Đang dự đoán cho dòng thứ 226 là 4.764957379793119
# ----- Đang dự đoán cho dòng thứ 227 là 4.676581663711314
# ----- Đang dự đoán cho dòng thứ 228 là 0.0
# ----- Đang dự đoán cho dòng thứ 229 là 4.412951480572724
# ----- Đang dự đoán cho dòng thứ 230 là 5.0
# ----- Đang dự đoán cho dòng thứ 231 là 4.884036462646434
# ----- Đang dự đoán cho dòng thứ 232 là 4.624229163078042
# ----- Đang dự đoán cho dòng thứ 233 là 4.385798687911149
# ----- Đang dự đoán cho dòng thứ 234 là 4.492638004238636
# ----- Đang dự đoán cho dòng thứ 235 là 5.0
# ----- Đang dự đoán cho dòng thứ 236 là 5.0
# ----- Đang dự đoán cho dòng thứ 237 là 5.0
# ----- Đang dự đoán cho dòng thứ 238 là 5.0
# ----- Đang dự đoán cho dòng thứ 239 là 5.0
# ----- Đang dự đoán cho dòng thứ 240 là 5.0
# ----- Đang dự đoán cho dòng thứ 241 là 4.719734679231043
# ----- Đang dự đoán cho dòng thứ 242 là 4.657994668756333
# ----- Đang dự đoán cho dòng thứ 243 là 4.999999999999999
# ----- Đang dự đoán cho dòng thứ 244 là 4.43361466395141
# ----- Đang dự đoán cho dòng thứ 245 là 5.0
# ----- Đang dự đoán cho dòng thứ 246 là 5.000000000000001
# ----- Đang dự đoán cho dòng thứ 247 là 4.245907462398155
# ----- Đang dự đoán cho dòng thứ 248 là 4.227603627976206
# ----- Đang dự đoán cho dòng thứ 249 là 4.8199364064801955
# ----- Đang dự đoán cho dòng thứ 250 là 5.0
# ----- Đang dự đoán cho dòng thứ 251 là 4.7548187556381665
# ----- Đang dự đoán cho dòng thứ 252 là 4.1777249547221
# ----- Đang dự đoán cho dòng thứ 253 là 4.807462210788942
# ----- Đang dự đoán cho dòng thứ 254 là 3.9925941476501987
# ----- Đang dự đoán cho dòng thứ 255 là 0.0
# ----- Đang dự đoán cho dòng thứ 256 là 4.7167412758048455
# ----- Đang dự đoán cho dòng thứ 257 là 4.285428005193507
# ----- Đang dự đoán cho dòng thứ 258 là 4.580064470091913
# ----- Đang dự đoán cho dòng thứ 259 là 5.0
# ----- Đang dự đoán cho dòng thứ 260 là 4.6637742189366405
# ----- Đang dự đoán cho dòng thứ 261 là 5.0
# ----- Đang dự đoán cho dòng thứ 262 là 4.805537320631984
# ----- Đang dự đoán cho dòng thứ 263 là 5.0
# ----- Đang dự đoán cho dòng thứ 264 là 3.8406364903948127
# ----- Đang dự đoán cho dòng thứ 265 là 4.6188198945800645
# ----- Đang dự đoán cho dòng thứ 266 là 5.0
# ----- Đang dự đoán cho dòng thứ 267 là 3.9988564514669265
# ----- Đang dự đoán cho dòng thứ 268 là 4.853301683005335
# ----- Đang dự đoán cho dòng thứ 269 là 5.0
# ----- Đang dự đoán cho dòng thứ 270 là 5.000000000000001
# ----- Đang dự đoán cho dòng thứ 271 là 4.002103023294664
# ----- Đang dự đoán cho dòng thứ 272 là 4.802225479874611
# ----- Đang dự đoán cho dòng thứ 273 là 5.000000000000001
# ----- Đang dự đoán cho dòng thứ 274 là 5.0
# ----- Đang dự đoán cho dòng thứ 275 là 4.631604236200251
# ----- Đang dự đoán cho dòng thứ 276 là 5.0
# ----- Đang dự đoán cho dòng thứ 277 là 4.849811350862794
# ----- Đang dự đoán cho dòng thứ 278 là 3.775961131053225
# Tổng thời gian dự đoán:  113.59509468078613

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import math

mse = mean_squared_error(X_test['rating'].tolist(), X_test_pred_rating)
print('----- MSE: ', mse)

rmse = math.sqrt(mse)
print('----- RMSE: ', rmse)

mae = mean_absolute_error(X_test['rating'].tolist(), X_test_pred_rating)
print('----- MAE: ',mae)

max = X_test['rating'].max()
min = X_test['rating'].min()
nmae = mae/(max-min)
print('----- NMAE: ', nmae)
# Out:
# ----- MSE:  2.715654645520048
# ----- RMSE:  1.6479243445983944
# ----- MAE:  0.9175446246820804
# ----- NMAE:  0.2293861561705201
